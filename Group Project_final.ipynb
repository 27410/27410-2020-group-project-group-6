# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline
import escher
from cobra.flux_analysis.phenotype_phase_plane import production_envelope, add_envelope

# %%
from cobra.io import read_sbml_model
model = read_sbml_model('../course-materials/data/iML1515.xml')
model

# %% [markdown]
# #### **L-Serine metabolite ID in different compartments**

# %%
for metabolite in model.metabolites.query('L-Serine', 'name'):
    print(metabolite.id)
# Out:
# ser__L_c
# ser__L_p
# ser__L_e

# %% [markdown]
# #### **Reactions with L-Serine in different compartments**

# %%
# Compartment - Cytosol
ser_reac_C = list()
for reaction in model.metabolites.ser__L_c.reactions:
    if reaction.id != 'BIOMASS_Ec_iML1515_core_75p37M' and reaction.id != 'BIOMASS_Ec_iML1515_WT_75p37M':
        ser_reac_C.append(reaction)
        print(reaction)
# Out:
# TRPS1: 3ig3p_c + ser__L_c --> g3p_c + h2o_c + trp__L_c
# SERt2rpp: h_p + ser__L_p --> h_c + ser__L_c
# PSSA140: cdpdtdecg_c + ser__L_c --> cmp_c + h_c + ps140_c
# DHBSH: 23dhbzs_c + h2o_c --> 23dhb_c + ser__L_c
# GHMT2r: ser__L_c + thf_c <=> gly_c + h2o_c + mlthf_c
# PSSA120: cdpdddecg_c + ser__L_c --> cmp_c + h_c + ps120_c
# SERt4pp: na1_p + ser__L_p --> na1_c + ser__L_c
# PSSA181: cdpdodec11eg_c + ser__L_c --> cmp_c + h_c + ps181_c
# TRPS2: indole_c + ser__L_c --> h2o_c + trp__L_c
# SERASr: atp_c + h_c + ser__L_c <=> ppi_c + seramp_c
# SERAT: accoa_c + ser__L_c <=> acser_c + coa_c
# SERD_L: ser__L_c --> nh4_c + pyr_c
# PSSA180: cdpdodecg_c + ser__L_c --> cmp_c + h_c + ps180_c
# PSSA141: cdpdtdec7eg_c + ser__L_c --> cmp_c + h_c + ps141_c
# GPDDA3: g3ps_c + h2o_c --> glyc3p_c + h_c + ser__L_c
# PSSA160: cdpdhdecg_c + ser__L_c --> cmp_c + h_c + ps160_c
# LSERDHr: nadp_c + ser__L_c <=> 2amsa_c + h_c + nadph_c
# SERtpp: ser__L_c --> ser__L_p
# PSSA161: cdpdhdec9eg_c + ser__L_c --> cmp_c + h_c + ps161_c
# PSP_L: h2o_c + pser__L_c --> pi_c + ser__L_c

# %%
# Compartment - Periplasm
ser_reac_P = list()
for reaction in model.metabolites.ser__L_p.reactions:
    ser_reac_P.append(reaction)
    print(reaction)
# Out:
# SERtpp: ser__L_c --> ser__L_p
# SERtex: ser__L_e <=> ser__L_p
# SERt2rpp: h_p + ser__L_p --> h_c + ser__L_c
# GPDDA3pp: g3ps_p + h2o_p --> glyc3p_p + h_p + ser__L_p
# PSP_Lpp: h2o_p + pser__L_p --> pi_p + ser__L_p
# SERt4pp: na1_p + ser__L_p --> na1_c + ser__L_c

# %%
# Compartment - Extracellular
ser_reac_E = list()
for reaction in model.metabolites.ser__L_e.reactions:
    ser_reac_E.append(reaction)
    print(reaction)
# Out:
# SERtex: ser__L_e <=> ser__L_p
# EX_ser__L_e: ser__L_e -->

# %% [markdown]
# ## WT MG1655 strain

# %%
## Flux Solution with Biomass objective
print("Max BM production [mmol gDW^-1 h^-1]:", model.optimize().objective_value)
print('Serine Production[mmol gDW^-1 h^-1]:',model.reactions.EX_ser__L_e.flux)
print('Ser_to_Gly_flux:',model.optimize().fluxes.GHMT2r)
print('Ser_to_Pyr_flux:',model.optimize().fluxes.SERD_L)
print("Theoretical max. yield [mmol_L-ser / mmol_glc]:", model.reactions.EX_ser__L_e.flux / (-1*model.reactions.EX_glc__D_e.flux))
WT_Solution = model.optimize()
# model.reactions.PFK_3.flux
# Out:
# Max BM production [mmol gDW^-1 h^-1]: 0.8769972144269618
# Serine Production[mmol gDW^-1 h^-1]: 0.0
# Ser_to_Gly_flux: 0.9783188951028198
# Ser_to_Pyr_flux: 0.0
# Theoretical max. yield [mmol_L-ser / mmol_glc]: 0.0

# %%
# Include Escher Map to capture WT fluxes
escher.Builder(map_name='iJO1366.Central metabolism with Serine',map_json='iJO1366.Central metabolism with Serine.json',reaction_data = WT_Solution.fluxes.to_dict()).display_in_notebook()
# Out:
# /usr/local/lib/python3.6/dist-packages/escher/plots.py:358 UserWarning: map_json overrides map_name
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="minxrqchku"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"minxrqchku"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": {"CYTDK2": 0.0, "XPPT": 0.0, "HXPRT": 0.0, "NDPK5": 0.0, "SHK3Dr": 0.33424030136518923, "NDPK6": 0.0, "NDPK8": 0.0, "DHORTS": -0.29010629354636686, "OMPDC": 0.29010629354636686, "PYNP2r": 0.0, "G5SD": 0.19386461923515202, "CS": 6.91300311088088, "ICDHyr": 6.91300311088088, "ALATA_L2": 0.0, "DURIPP": 0.0, "ACALD": 0.0, "PTRCTA": 0.0, "ACS": 0.0, "CYSDS": 0.0, "MAN6PI": 0.0, "PPA": 3.0708609971405685, "APRAUR": 0.0003911407576344988, "TRPAS2": -0.049851152659671785, "PPCK": 0.0, "ME1": 0.0, "DB4PS": 0.0007822815152689976, "ALAR": 0.03655499789174462, "RBFK": 0.00019557037881728635, "ALATA_L": -0.881387462482383, "XYLK": 0.0, "RBK": 0.0, "GLYK": 0.0, "PPM": -0.8185400881021674, "ASPTA": -2.5676926153352904, "ACP1_FMN": 0.0, "RBFSb": 0.0003911407576344988, "NDP3": 0.0, "CDPPH": 0.0, "NDP7": 0.0, "FBP": 0.0, "EX_pi_e": -0.8459567750196921, "GLGC": 0.0, "ALATA_D2": 0.0, "PYK": 0.0, "SHCHD2": 0.00019557037881721246, "EX_co2_e": 24.003293272975775, "A5PISO": 0.03412571560778194, "PMDPHT": 0.0003911407576344988, "CPPPGO": 0.00019557037881721246, "EX_met__L_e": 0.0, "GTHOr": 0.21704102462081426, "ILETA": -0.25479312371025076, "DHORD5": 0.29010629354636686, "EX_metsox_S__L_e": 0.0, "GLYCTO2": 0.0, "VALTA": 0.0, "GLYCTO3": 0.0, "IPPMIb": -0.3951144320129935, "GLYCTO4": 0.0, "ORPT": -0.29010629354636686, "RBFSa": 0.0007822815152689976, "ACHBS": 0.25479312371025076, "PFK_3": 6.57186939552026, "DHAD2": 0.25479312371025076, "ACLS": 0.7668174233868602, "TRPS2": 0.0, "PSCVT": 0.33424030136518923, "G3PD5": 0.0, "G1PP": 0.0, "PFL": 0.0, "EX_acgam_e": 0.0, "ANS": 0.049851152659671785, "FRD2": 0.2886802960757082, "FRD3": 37.99704395949199, "ANPRT": 0.049851152659671785, "POX": 0.0, "CHORM": 0.28360686719024863, "PTAr": -0.5105755002783762, "CHORS": 0.33424030136518923, "IGPS": 0.049851152659671785, "ACKr": 0.5105755002783762, "EX_cellb_e": 0.0, "EX_crn_e": 0.0, "EX_hxan_e": 0.0, "EX_ile__L_e": 0.0, "EX_chol_e": 0.0, "EX_fe3_e": -0.0, "LEUTAi": 0.3951144320129935, "EX_lac__L_e": 0.0, "EX_leu__L_e": 0.0, "EX_glcn_e": 0.0, "EX_no3_e": 0.0, "EX_h_e": 8.058200328043734, "DMATT": 0.00024380522561069534, "EX_orn_e": 0.0, "GRTT": 0.00024380522561069534, "EX_gln__L_e": 0.0, "UPP3S": 0.0003911407576344249, "EX_pro__L_e": 0.0, "EX_glyc_e": 0.0, "UPPDC1": 0.00019557037881721246, "EX_man_e": 0.0, "TMDPP": 0.0, "EX_ade_e": 0.0, "EX_mn2_e": -0.0006060050751690306, "EX_4abut_e": 0.0, "EX_ac_e": 0.0, "EX_akg_e": 0.0, "EX_ala__L_e": 0.0, "EX_arg__L_e": 0.0, "EX_asp__L_e": 0.0, "EX_pyr_e": 0.0, "EX_succ_e": 0.0, "EX_thymd_e": 0.0, "EX_rib__D_e": 0.0, "EX_tyr__L_e": 0.0, "EX_cytd_e": 0.0, "EX_dcyt_e": 0.0, "MOAT": 0.01706285780389097, "EX_fum_e": 0.0, "EX_sbt__D_e": 0.0, "EX_glu__L_e": 0.0, "UDCPDPS": 4.82348467934829e-05, "ECOAH6": 0.24385433745470325, "USHD": 0.01706285780389097, "EX_gua_e": 0.0, "ENO": 15.598897532203388, "FBA": 0.0, "HCO3E": 0.4609707838360071, "MGSA": 0.0, "IMPC": -0.4757990527375382, "IMPD": 0.21331027847064113, "PPS": 0.0, "ECOAH4": 0.3121057686702671, "LPADSS": 0.01706285780389097, "GLUTRS": 0.0031291260610753994, "TDSK": 0.01706285780389097, "PGI": 7.644633780205904, "TMPPP": 0.00019557037881721246, "EX_btn_e": 0.0, "PGK": -17.105433603549997, "EX_ptrc_e": 0.0, "EDA": 0.0, "EX_spmd_e": -0.0, "EX_thym_e": -0.0, "EX_xtsn_e": 0.0, "NTPP1": 0.0, "URIK1": 0.0, "URIK2": 0.0, "NTPP2": 0.0, "PGL": 2.355366219794095, "NTPTP1": 0.0, "NTPTP2": 0.0, "CYTDK1": 0.0, "RPE": 0.8899957028433988, "DHQTi": 0.33424030136518923, "IPMD": 0.3951144320129935, "AIRC3": -0.3927140906371567, "TALA": -5.959946963794783, "PUNP1": -0.0005902191253093453, "PUNP2": 0.0, "PUNP3": 0.0, "ADSL2r": 0.3927140906371567, "TKT1": 0.6119224317254766, "EX_fe2_e": -0.014085452260911433, "PUNP5": 0.0, "PUNP6": 0.0, "PUNP7": 0.0, "G6PDA": 0.0, "RNDR1": 0.0, "ALCD2x": 0 ...

# %%
## MG1655 Serine Production as Objective

# %%
# Flux Solution with Serine objective
with model:
    model.objective = model.reactions.EX_ser__L_e
    Ser_Prodn = model.optimize();
#Output solution
#print("Max. BM production [mmol gDW^-1 h^-1]:", model.optimize().objective_value)
    print("BM production [mmol gDW^-1 h^-1]:", model.reactions.BIOMASS_Ec_iML1515_core_75p37M.flux)
    print('Max Serine Production[mmol gDW^-1 h^-1]:',model.reactions.EX_ser__L_e.flux)
    print('Ser_to_Gly_flux:',model.optimize().fluxes.GHMT2r)
    print('Ser_to_Pyr_flux:',model.optimize().fluxes.SERD_L)
    print("Theoretical max. yield [mmol_L-ser / mmol_glc]:", model.reactions.EX_ser__L_e.flux / (-1*model.reactions.EX_glc__D_e.flux))
# Out:
# BM production [mmol gDW^-1 h^-1]: 0.0
# Max Serine Production[mmol gDW^-1 h^-1]: 20.625882352941172
# Ser_to_Gly_flux: -0.6258823529411746
# Ser_to_Pyr_flux: 0.0
# Theoretical max. yield [mmol_L-ser / mmol_glc]: 2.0625882352941174

# %%
escher.Builder(map_name='iJO1366.Central metabolism with Serine',map_json='iJO1366.Central metabolism with Serine.json',reaction_data = Ser_Prodn.fluxes.to_dict()).display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="jidzbeuopu"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"jidzbeuopu"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": {"CYTDK2": 0.0, "XPPT": 0.0, "HXPRT": 0.0, "NDPK5": 0.0, "SHK3Dr": 0.0, "NDPK6": 0.0, "NDPK8": 0.0, "DHORTS": 0.0, "OMPDC": 0.0, "PYNP2r": 0.0, "G5SD": 0.0, "CS": 0.0, "ICDHyr": 0.0, "ALATA_L2": 0.0, "DURIPP": 0.0, "ACALD": 0.0, "PTRCTA": 0.0, "ACS": 0.0, "CYSDS": 0.0, "MAN6PI": 0.0, "PPA": 0.0, "APRAUR": 0.0, "TRPAS2": 0.0, "PPCK": 0.0, "ME1": 0.0, "DB4PS": 0.0, "ALAR": 0.0, "RBFK": 0.0, "ALATA_L": 0.0, "XYLK": 0.0, "RBK": 0.0, "GLYK": 0.0, "PPM": 0.0, "ASPTA": -0.6258823529411746, "ACP1_FMN": 0.0, "RBFSb": 0.0, "NDP3": 0.0, "CDPPH": 0.0, "NDP7": 0.0, "FBP": 0.0, "EX_pi_e": 0.0, "GLGC": 0.0, "ALATA_D2": 0.0, "PYK": 0.0, "SHCHD2": 0.0, "EX_co2_e": -1.8776470588235237, "A5PISO": 0.0, "PMDPHT": 0.0, "CPPPGO": 0.0, "EX_met__L_e": 0.0, "GTHOr": 0.0, "ILETA": 0.0, "DHORD5": 0.0, "EX_metsox_S__L_e": 0.0, "GLYCTO2": 0.0, "VALTA": 0.0, "GLYCTO3": 0.0, "IPPMIb": 0.0, "GLYCTO4": 0.0, "ORPT": 0.0, "RBFSa": 0.0, "ACHBS": 0.0, "PFK_3": 10.0, "DHAD2": 0.0, "ACLS": 0.0, "TRPS2": 0.0, "PSCVT": 0.0, "G3PD5": 0.0, "G1PP": 0.0, "PFL": 0.6258823529411746, "EX_acgam_e": 0.0, "ANS": 0.0, "FRD2": 0.0, "FRD3": 16.87058823529412, "ANPRT": 0.0, "POX": 0.0, "CHORM": 0.0, "PTAr": 0.0, "CHORS": 0.0, "IGPS": 0.0, "ACKr": 0.0, "EX_cellb_e": 0.0, "EX_crn_e": 0.0, "EX_hxan_e": 0.0, "EX_ile__L_e": 0.0, "EX_chol_e": 0.0, "EX_fe3_e": -0.0, "LEUTAi": 0.0, "EX_lac__L_e": 0.0, "EX_leu__L_e": 0.0, "EX_glcn_e": 0.0, "EX_no3_e": 0.0, "EX_h_e": 20.625882352941233, "DMATT": 0.0, "EX_orn_e": 0.0, "GRTT": 0.0, "EX_gln__L_e": 0.0, "UPP3S": 0.0, "EX_pro__L_e": 0.0, "EX_glyc_e": 0.0, "UPPDC1": 0.0, "EX_man_e": 0.0, "TMDPP": 0.0, "EX_ade_e": 0.0, "EX_mn2_e": 0.0, "EX_4abut_e": 0.0, "EX_ac_e": 0.0, "EX_akg_e": 0.0, "EX_ala__L_e": 0.0, "EX_arg__L_e": 0.0, "EX_asp__L_e": 0.0, "EX_pyr_e": 0.0, "EX_succ_e": 0.0, "EX_thymd_e": 0.0, "EX_rib__D_e": 0.0, "EX_tyr__L_e": 0.0, "EX_cytd_e": 0.0, "EX_dcyt_e": 0.0, "MOAT": 0.0, "EX_fum_e": 0.0, "EX_sbt__D_e": 0.0, "EX_glu__L_e": 0.0, "UDCPDPS": 0.0, "ECOAH6": 0.0, "USHD": 0.0, "EX_gua_e": 0.0, "ENO": 0.0, "FBA": 0.0, "HCO3E": 0.0, "MGSA": 0.0, "IMPC": 0.0, "IMPD": 0.0, "PPS": 0.6258823529411746, "ECOAH4": 0.0, "LPADSS": 0.0, "GLUTRS": 0.0, "TDSK": 0.0, "PGI": 0.0, "TMPPP": 0.0, "EX_btn_e": 0.0, "PGK": -19.999999999999996, "EX_ptrc_e": 0.0, "EDA": 0.0, "EX_spmd_e": -0.0, "EX_thym_e": -0.0, "EX_xtsn_e": 0.0, "NTPP1": 0.0, "URIK1": 0.0, "URIK2": 0.0, "NTPP2": 0.0, "PGL": 0.0, "NTPTP1": 0.0, "NTPTP2": 0.0, "CYTDK1": 0.0, "RPE": 0.0, "DHQTi": 0.0, "IPMD": 0.0, "AIRC3": 0.0, "TALA": -10.0, "PUNP1": 0.0, "PUNP2": 0.0, "PUNP3": 0.0, "ADSL2r": 0.0, "TKT1": 0.0, "EX_fe2_e": 0.0, "PUNP5": 0.0, "PUNP6": 0.0, "PUNP7": 0.0, "G6PDA": 0.0, "RNDR1": 0.0, "ALCD2x": 0.0, "RNDR3": 0.0, "RNDR4": 0.0, "ALDD2y": 0.0, "TMDS": 0.0, "RMI": 0.0, "TMDK1": 0.0, "LYSAM": 0.0, "PPCDC": 0.0, "FTHFD": 0.0, "EX_glc__D_e": -10.0, "DHAD1": 0.0, "IPPMIa": 0.0, "EX_alltn_e": 0.0, "G3PD7": 0.0, "EDD": 0.0, "EX_ura_e": -0.0, "NADH9": 0.0, "EX_val__L_e": 0.0, "NADH10": 0.0, "ADK4": 0.0, "INSK": 0.0, "MDH": 0.0, "ABTA": 0.0, "EX_xan_e": 0.0, "FUM": 0.0, "FMNAT": 0.0, "PYDXNK": 0.0, "PYAM5PO": 0.0, "SSALx": 0.0, "ASPT": 0.0, "OHPBAT": 0.0, "SERD_L": 0.0, "EX_dgsn_e": 0.0, "NADDP": 0.0, "EX_arab__L_e": 0.0, "EX_fru_e": 0.0, "THRD": 0.6258823529411746, "HEX4": 0.0, "EX_gal_e": 0.0, "NMNAT": 0.0, "EX_xyl__D_e": 0.0, "KARA1": 0.0, "HMPK1": 0.0, "KARA2": 0.0, "EX_duri_e": 0.0, "EX_for_e": 0.0, "EX_gly_e": 0.0, "EX_h2_e": 0.0, "EX_lys__L_e": 0.0, "ACCOAC": 0.0, "NADK": 0.0, "GLXCL": 0.0, "ICHORS_copy2": 0.0, "SUCBZS": 0.0, "DHBD": 0.0, "ICHORT": 0.0, "EX_ser__L_e": 20.625882352941172, "EX_thm_e": 0.0, "EX_trp__L_e": 0.0, "GLUTRR": 0.0, "GLCS1": 0.0, "GLCP": 0.0, "EX_din_e": 0.0, "RBK_L1": 0.0, "RBP4E": 0.0, "TARTD": 0.0, "NTD2": 0.0, "GLCRAL": 0.0, "NTD4": 0.0, "NTD5":  ...

# %% [markdown]
# ### Serine Degradation Pathways KO

# %%
# Reactions to L-serine
# model.reactions.PGCD   # 3pg_c + nad_c --> 3php_c + h_c + nadh_c
# model.reactions.PSERT  # 3php_c + glu__L_c --> akg_c + pser__L_c
# model.reactions.PSP_L    # h2o_c + pser__L_c --> pi_c + ser__L_c

# Reactions from L-serine
#model.reactions.GHMT2r   GHMT2r: ser__L_c + thf_c <=> gly_c + h2o_c + mlthf_c
#model.reactions.LSERDHr LSERDHr: nadp_c + ser__L_c <=> 2amsa_c + h_c + nadph_c
#model.reactions.SERD_L  SERD_L: ser__L_c --> nh4_c + pyr_c
#model.reactions.TRPS1 TRPS1: 3ig3p_c + ser__L_c --> g3p_c + h2o_c + trp__L_c
#model.reactions.TRPS2 TRPS2: indole_c + ser__L_c --> h2o_c + trp__L_c
# From_ser_Rxn = [model.reactions.GHMT2r, model.reactions.LSERDHr, model.reactions.SERD_L, model.reactions.TRPS1, model.reactions.TRPS2]
# for rxn in From_ser_Rxn:
#     print(rxn)

# %%
#1. GlyA Knockout
#model.reactions.GHMT2r   GHMT2r: ser__L_c + thf_c <=> gly_c + h2o_c + mlthf_c

# 2. Constrain Glycine Exchange Flux 
# Since glyA is an essential reaction, glycine is added in the medium, so a flux constraint is added


# 3. Pyruvate reaction knockout
#model.reactions.SERD_L  SERD_L: ser__L_c --> nh4_c + pyr_c
# Of the 5 genes of the reaction SERD_L, only three were knocked out in the Paper

#Finding Serine to Pyruvate node genes
 #Ser_to_Pyr_genes = list()
 #Genes_to_KO = list() 
 #for genes in model.reactions.SERD_L.genes:
 #        Ser_to_Pyr_genes.append(genes)
 #        print(genes,genes.name)   

with model:
    model.reactions.GHMT2r.knock_out
    model.reactions.EX_gly_e.bounds =(-5,1000)
    model.genes.b1814.knock_out() #sdaA
    model.genes.b2797.knock_out() #sdaB
    model.genes.b4471.knock_out() #tdcG
    print('Biomass_Objective:',model.optimize().objective_value)
    print('Serine Production:',model.optimize().fluxes.EX_ser__L_e)
    print('Ser_to_Gly_flux:',model.optimize().fluxes.GHMT2r)
    print('Ser_to_Pyr_flux:',model.optimize().fluxes.SERD_L)
    print('Glycine uptake flux:',model.optimize().fluxes.EX_gly_e)
    print(model.objective)
# Out:
# Biomass_Objective: 0.9931722616268956
# Serine Production: 0.0
# Ser_to_Gly_flux: -1.3908659382777402
# Ser_to_Pyr_flux: 0.7926762987553375
# Glycine uptake flux: -5.0
# Maximize
# 1.0*BIOMASS_Ec_iML1515_core_75p37M - 1.0*BIOMASS_Ec_iML1515_core_75p37M_reverse_35685

# %%
#WT flux of serACB reactions
# Solution.fluxes.PGCD  = 1.51
# Solution.fluxes.PSERT  = 1.51
# Solution.fluxes.PSP_L  = 1.51

#4. Constraint flux through 
# model.reactions.PGCD   # 3pg_c + nad_c --> 3php_c + h_c + nadh_c
# model.reactions.PSERT  # 3php_c + glu__L_c --> akg_c + pser__L_c
# model.reactions.PSP_L    # h2o_c + pser__L_c --> pi_c + ser__L_c

with model:
    model.reactions.GHMT2r.knock_out
    model.reactions.EX_gly_e.bounds =(-5,1000)
    model.reactions.SERD_L.knock_out
    # Serine pathway overexpression
    model.reactions.PGCD.bounds =(20,20)
    model.reactions.PSERT.bounds =(20,20)
    model.reactions.PSP_L.bounds =(20,20)
    print(model.objective)
    print('Biomass_Objective:',model.optimize().objective_value)
    print('Serine Production:',model.optimize().fluxes.EX_ser__L_e)
    print('Ser_to_Gly_flux:',model.optimize().fluxes.GHMT2r)
    print('Ser_to_Pyr_flux:',model.optimize().fluxes.SERD_L)
    print('Glycine uptake flux:',model.optimize().fluxes.EX_gly_e)
     

# What is the correct way of modeling gene overexpression?
# Why despite KO of serine degradation and overexpression of production pathway, there is no serine production?
# Out:
# Maximize
# 1.0*BIOMASS_Ec_iML1515_core_75p37M - 1.0*BIOMASS_Ec_iML1515_core_75p37M_reverse_35685
# Biomass_Objective: 0.8592409235863779
# Serine Production: 0.0
# Ser_to_Gly_flux: -1.5404349654167269
# Ser_to_Pyr_flux: 21.022912438658803
# Glycine uptake flux: -5.0

# %%
ppp_ser = production_envelope(model,
                    reactions=[model.reactions.EX_ser__L_e],
                   objective=model.reactions.EX_ser__L_e)

# %% [markdown]
# ### Differential FVA to identify gene modulation targets

# %%
from cameo.visualization.plotting.with_plotly import PlotlyPlotter
from cameo.visualization import plotting
from cameo.strain_design.deterministic import DifferentialFVA
from cameo import load_model
import pandas as pd
pd.set_option('display.max_rows', None)
plotter = PlotlyPlotter()
model = load_model('../course-materials/data/iML1515.xml')

# %%
model.reactions.EX_o2_e.lower_bound = 0
reference_model = model.copy()
biomass_rxn = reference_model.reactions.BIOMASS_Ec_iML1515_core_75p37M
biomass_rxn.lower_bound = 0
target = reference_model.metabolites.ser__L_e

# %%
diff_fva = DifferentialFVA(design_space_model=model,
                           reference_model=reference_model,
                           objective=target,
                           variables=[biomass_rxn],
                           normalize_ranges_by=biomass_rxn,
                           points=10)

# %%
# Takes 7 min!

# %time result = diff_fva.run(surface_only=True)
#result.plot()
result
# Out:
# HBox()
# CPU times: user 7min 45s, sys: 0 ns, total: 7min 45s
# Wall time: 7min 46s
# interactive(children=(IntSlider(value=5, description='solution', max=9, min=1), Output()), _dom_classes=('widg…

# %%
type(result)
# Out:
# cameo.strain_design.deterministic.flux_variability_based.DifferentialFVAResult

# %%
# result.plot(5, variables=['EX_ser__L_e', 'GHMT2r', 'SERD_L', 'PSP_L'])
result.plot?

# %% [markdown]
# ### FSEOF to identify gene modulation targets

# %% [markdown]
# #### __OMIT IF WITHIN AVAILABLE TIMEFRAME BYPRODUCT STUDY NOT POSSIBLE__

# %%
#akg_c_reac = []
#for reaction in model.metabolites.akg_c.reactions:
#        akg_c_reac.append(reaction)
#        print(reaction)

# %%
#ppp_ser = production_envelope(model,
#                    reactions=[model.reactions.EX_ser__L_e],
 #                   objective=model.reactions.EX_ser__L_e)

# %%
#ppp_ser

# %%
 #Metabolites to L-serine

# model.metabolites.get_by_id('3pg_c')
# model.metabolites.get_by_id('3php_c')
# model.metabolites.get_by_id('pser__L_c')
model.metabolites.get_by_id('akg_c')
# Out:
# <Metabolite akg_c at 0x7f10e649a128>

# %%
# Byproduct Reaction 
# model.reactions.AHGDx.annotation - Promiscuous reaction resulting in hydroxyglutarate byproduct formation- 1.1.1.399
model.reactions.AHGDx
# Out:
# <Reaction AHGDx at 0x7f10e4ccd668>

# %% [markdown]
# ## Flux variability Analysis

# %% [markdown]
# Calculate all flux ranges of all reactions in the model

# %%
from cobra.flux_analysis import flux_variability_analysis

# %%
result = flux_variability_analysis(model,loopless= True)
result

# %%
type(result)

# %%
result.describe()

# %% [markdown]
# Writing Absolute flux differences to CSV

# %%
df3 = abs(result.maximum - result.minimum)
df3.fobje
# find reactions showing up in red, these are futile cycles
sum(abs(result.maximum - result.minimum))

# %%
df3.value_counts(sort=True)

# %%
model.objective

# %%
from cameo.flux_analysis.analysis import phenotypic_phase_plane
production_envelope = phenotypic_phase_plane(model, 
                                             variables=[model.reactions.BIOMASS_Ecoli_core_w_GAM],
                                             objective=model.metabolites.succ_e)
production_envelope.plot(height=400)

# %%
print(model.reactions.GLCt2pp)
